# %% [markdown]
# # Bemba TTS Training Notebook
#
# This notebook trains a Text-to-Speech model for Bemba language using the BembaSpeech dataset. We'll use Coqui TTS framework for training.

# %% [markdown]
# ## 1. Import Required Libraries
#
# Import necessary libraries for TTS training, including Coqui TTS, audio processing, and data handling.

# %%
# Install Coqui TTS if not already installed
try:
    import TTS
    print("✅ Coqui TTS already installed")
except ImportError:
    print("Installing Coqui TTS...")
    # !pip install coqui-tts
    print("✅ Coqui TTS installed")

import os
import pandas as pd
import numpy as np
from pathlib import Path
import librosa
from TTS.api import TTS
from TTS.utils.manage import ModelManager
from TTS.utils.synthesizer import Synthesizer
# Out:
# ✅ Coqui TTS already installed

# %%
# Check if BembaSpeech dataset exists
if not os.path.exists('BembaSpeech'):
    print("❌ BembaSpeech dataset not found!")
    print("Please clone it first: git clone https://github.com/csikasote/BembaSpeech.git")
    raise FileNotFoundError("BembaSpeech dataset missing")

print("✅ BembaSpeech dataset found")
# Out:
# ✅ BembaSpeech dataset found

# %% [markdown]
# ## 2. Load and Prepare Data
#
# Load the BembaSpeech dataset and prepare it for TTS training by extracting text and audio paths.

# %%
# Load BembaSpeech dataset
dataset_path = 'BembaSpeech/bem'

# Load training data (files are TSV, not CSV)
train_df = pd.read_csv(f'{dataset_path}/train.tsv', sep='\t')
dev_df = pd.read_csv(f'{dataset_path}/dev.tsv', sep='\t')
test_df = pd.read_csv(f'{dataset_path}/test.tsv', sep='\t')

print(f"Training samples: {len(train_df)}")
print(f"Dev samples: {len(dev_df)}")
print(f"Test samples: {len(test_df)}")

# Sample data
print(train_df.head())

# Prepare metadata for TTS training
def prepare_metadata(df, audio_dir):
    metadata = []
    for _, row in df.iterrows():
        audio_path = f"{audio_dir}/{row['audio']}"  # Column is 'audio', not 'audio_filepath'
        text = row['sentence']  # Column is 'sentence', not 'text'
        metadata.append(f"{audio_path}|{text}")
    return metadata

train_metadata = prepare_metadata(train_df, f"{dataset_path}/audio")
dev_metadata = prepare_metadata(dev_df, f"{dataset_path}/audio")

# Save metadata files
with open('train_metadata.txt', 'w') as f:
    f.write('\n'.join(train_metadata))

with open('dev_metadata.txt', 'w') as f:
    f.write('\n'.join(dev_metadata))
# Out:
# Training samples: 12421
# Dev samples: 1700
# Test samples: 1368
#                                     audio  \
# 0  01-200921-192247_bem_d31_elicit_16.wav
# 1   03-200921-160552_bem_798_elicit_2.wav
# 2  01-201002-002057_bem_fb0_elicit_31.wav
# 3  01-180101-223427_bem_d31_elicit_25.wav
# 4   01-200930-150533_bem_fb0_elicit_1.wav
#
#                                             sentence
# 0  cisuma ukwibukisho kuti iciputulwa icikalamba ...
# 1  umutitikisha wamu ndupwa namu mayanda milandu ...
# 2  kwena umutima tawakalipishe atile ndeisaisanga...
# 3  camulengele ukwenda ubulendo ubwayafya kabili ...
# 4  joni nao ati nga iwe amaka ukwete ayakunjipush...

# %% [markdown]
# ## 3. Define the Model
#
# We'll use a pre-trained TTS model and fine-tune it on Bemba data. For this demo, we'll use a simple TTS model setup.

# %%
# For TTS training, we'll use Coqui TTS configuration
# Note: Full training requires significant compute resources
# This is a simplified setup for demonstration

# Define TTS model configuration
model_config = {
    'model': 'tts_models/en/ljspeech/tacotron2-DDC_ph',  # Base English model
    'vocoder': 'vocoder_models/en/ljspeech/hifigan_v2',
    'language': 'en',  # We'll adapt for Bemba
}

# Initialize TTS with pre-trained model
tts = TTS(model_name=model_config['model'], 
          vocoder_name=model_config['vocoder'])

print("TTS Model loaded successfully")
print(f"Model: {model_config['model']}")
print(f"Vocoder: {model_config['vocoder']}")
# Out:
# TTS Model loaded successfully
# Model: tts_models/en/ljspeech/tacotron2-DDC_ph
# Vocoder: vocoder_models/en/ljspeech/hifigan_v2

# %% [markdown]
# ## 4. Compile the Model
#
# Configure the TTS model settings and prepare for inference or fine-tuning.

# %%
# TTS models are pre-compiled with default settings
# Configuration is handled internally by the model
# Default sample rate is typically 22050 Hz with silence trimming enabled

print("TTS Model ready for inference")
print("Using default audio settings (22kHz sample rate, silence trimming enabled)")
# Out:
# TTS Model ready for inference
# Using default audio settings (22kHz sample rate, silence trimming enabled)

# %% [markdown]
# ## 5. Train the Model
#
# Note: Full TTS training requires significant computational resources and time. For this demo, we'll use the pre-trained model for inference. To train on Bemba data, use Coqui TTS training scripts.

# %%
# Training command (run in terminal, not in notebook for long training)
# python -m TTS.bin.train_tts --config_path config.json --restore_path <pretrained_model_path>

print("For full training, use:")
print("python -m TTS.bin.train_tts --config_path bemba_tts_config.json --restore_path pretrained_model.pth.tar")
# Out:
# For full training, use:
# python -m TTS.bin.train_tts --config_path bemba_tts_config.json --restore_path pretrained_model.pth.tar

# %% [markdown]
# ## 6. Evaluate the Model
#
# Test the TTS model by generating audio for sample Bemba phrases.

# %%
# Test TTS with Bemba phrases
bemba_phrases = [
    "Umuntu wawonekera",  # Person detected
    "Imoto yawonekera",   # Car detected
    "Ibayisikilo yawonekera",  # Bicycle detected
    "Iciti cawonekera",   # Chair detected
    "Itabule yawonekera"  # Table detected
]

print("⚠️  WARNING: This uses English TTS model, so pronunciation will be English phonetics, not authentic Bemba.")
print("For proper Bemba audio, record native speakers or train a custom Bemba TTS model.\n")

for i, phrase in enumerate(bemba_phrases):
    print(f"Generating audio for: {phrase}")
    try:
        tts.tts_to_file(text=phrase, file_path=f"bemba_sample_{i}.wav")
        print(f"✅ Saved: bemba_sample_{i}.wav")
    except Exception as e:
        print(f"❌ Error generating {phrase}: {e}")
# Out:
# ⚠️  WARNING: This uses English TTS model, so pronunciation will be English phonetics, not authentic Bemba.
# For proper Bemba audio, record native speakers or train a custom Bemba TTS model.
#
# Generating audio for: Umuntu wawonekera
# ✅ Saved: bemba_sample_0.wav
# Generating audio for: Imoto yawonekera
# ✅ Saved: bemba_sample_0.wav
# Generating audio for: Imoto yawonekera
# ✅ Saved: bemba_sample_1.wav
# Generating audio for: Ibayisikilo yawonekera
# ✅ Saved: bemba_sample_1.wav
# Generating audio for: Ibayisikilo yawonekera
# ✅ Saved: bemba_sample_2.wav
# Generating audio for: Iciti cawonekera
# ✅ Saved: bemba_sample_2.wav
# Generating audio for: Iciti cawonekera
# ✅ Saved: bemba_sample_3.wav
# Generating audio for: Itabule yawonekera
# ✅ Saved: bemba_sample_3.wav
# Generating audio for: Itabule yawonekera
# ✅ Saved: bemba_sample_4.wav
# ✅ Saved: bemba_sample_4.wav

# %% [markdown]
# ## 7. Make Predictions
#
# Generate audio files for all object detection phrases that can be used in the Android app.

# %% [markdown]
# ## Translation Strategy
#
# Instead of translating full phrases, we translate only the object names and append language-specific suffixes:
# - **Nyanja**: `[object] yawonekera` (e.g., "munthu yawonekera" = "person detected")
# - **Bemba**: `[object] yamoneka` (e.g., "umuntu yamoneka" = "person detected")
#
# This reduces the translation workload to only 181 object names instead of 181 full phrases.

# %%
# Generate audio for all 181 object detection labels
# Strategy: Translate only object names, then append language-specific suffix
import os
import re
import pandas as pd

# Path to the label map
label_map_path = 'app/src/main/assets/labelmap.txt'

# Read all labels from the file
try:
    with open(label_map_path, 'r') as f:
        labels = [line.strip() for line in f.readlines()]
    print(f"✅ Successfully read {len(labels)} labels from {label_map_path}")
except FileNotFoundError:
    print(f"❌ Error: {label_map_path} not found. Make sure the path is correct.")
    labels = []

# Language-specific suffixes
SUFFIX_NYANJA = "yawonekera"  # "detected" in Nyanja
SUFFIX_BEMBA = "yamoneka"     # "detected" in Bemba

# --- Translation Logic ---
# Option 1: Load translations from CSV (if available)
translations_file = 'translations.csv'
object_translations = {}

try:
    df = pd.read_csv(translations_file)
    for _, row in df.iterrows():
        english = row['English']
        nyanja = row['Nyanja'] if pd.notna(row['Nyanja']) else english
        bemba = row['Bemba'] if pd.notna(row['Bemba']) else english
        object_translations[english] = {'nyanja': nyanja, 'bemba': bemba}
    print(f"✅ Loaded translations from {translations_file}")
except FileNotFoundError:
    print(f"⚠️  {translations_file} not found. Using English object names as placeholders.")
    for label in labels:
        object_translations[label] = {'nyanja': label, 'bemba': label}

# Generate phrases for both languages
nyanja_phrases = {}
bemba_phrases = {}

for label in labels:
    sanitized_label = re.sub(r'[^a-zA-Z0-9_]', '', label.replace(' ', '_'))
    
    # Get translation or use English as fallback
    trans = object_translations.get(label, {'nyanja': label, 'bemba': label})
    
    # Create complete phrases
    nyanja_phrases[sanitized_label] = f"{trans['nyanja']} {SUFFIX_NYANJA}"
    bemba_phrases[sanitized_label] = f"{trans['bemba']} {SUFFIX_BEMBA}"

print(f"\nGenerated {len(nyanja_phrases)} Nyanja phrases and {len(bemba_phrases)} Bemba phrases.")
print("⚠️  WARNING: This uses an English TTS model, so pronunciation will be English phonetics.")
print("For proper audio, record native speakers.\n")

# Generate audio for both languages
for lang_name, phrases, output_dir in [
    ("Nyanja", nyanja_phrases, "nyanja_audio_all"),
    ("Bemba", bemba_phrases, "bemba_audio_all")
]:
    print(f"\n{'='*60}")
    print(f"Generating {lang_name} audio files...")
    print(f"{'='*60}\n")
    
    os.makedirs(output_dir, exist_ok=True)
    
    for obj_filename, phrase in phrases.items():
        output_path = f"{output_dir}/{lang_name.lower()}_{obj_filename}.wav"
        print(f"Generating '{phrase}'")
        try:
            tts.tts_to_file(text=phrase, file_path=output_path)
            print(f"✅ Saved: {output_path}")
        except Exception as e:
            print(f"❌ Error: {e}")

print(f"\n{'='*60}")
print("Audio generation complete!")
print(f"Nyanja files: nyanja_audio_all/")
print(f"Bemba files: bemba_audio_all/")
print("\nNext steps:")
print("1. Fill in translations.csv with proper Nyanja/Bemba object names")
print("2. Record native speakers saying each phrase")
print("3. Convert to MP3 and copy to app/src/main/res/raw/")
print(f"{'='*60}")
# Out:
# ✅ Successfully read 181 labels from app/src/main/assets/labelmap.txt
#
# Generated 181 placeholder phrases.
# ⚠️  WARNING: This uses an English TTS model, so pronunciation will be English phonetics, not authentic Bemba.
# For proper Bemba audio, record native speakers or train a custom Bemba TTS model.
#
# Generating for 'person': person yawonekera
# ❌ Error generating audio for person: name 'tts' is not defined
# Generating for 'bicycle': bicycle yawonekera
# ❌ Error generating audio for bicycle: name 'tts' is not defined
# Generating for 'car': car yawonekera
# ❌ Error generating audio for car: name 'tts' is not defined
# Generating for 'motorcycle': motorcycle yawonekera
# ❌ Error generating audio for motorcycle: name 'tts' is not defined
# Generating for 'airplane': airplane yawonekera
# ❌ Error generating audio for airplane: name 'tts' is not defined
# Generating for 'bus': bus yawonekera
# ❌ Error generating audio for bus: name 'tts' is not defined
# Generating for 'train': train yawonekera
# ❌ Error generating audio for train: name 'tts' is not defined
# Generating for 'truck': truck yawonekera
# ❌ Error generating audio for truck: name 'tts' is not defined
# Generating for 'boat': boat yawonekera
# ❌ Error generating audio for boat: name 'tts' is not defined
# Generating for 'traffic_light': traffic light yawonekera
# ❌ Error generating audio for traffic_light: name 'tts' is not defined
# Generating for 'fire_hydrant': fire hydrant yawonekera
# ❌ Error generating audio for fire_hydrant: name 'tts' is not defined
# Generating for 'street_sign': street sign yawonekera
# ❌ Error generating audio for street_sign: name 'tts' is not defined
# Generating for 'stop_sign': stop sign yawonekera
# ❌ Error generating audio for stop_sign: name 'tts' is not defined
# Generating for 'parking_meter': parking meter yawonekera
# ❌ Error generating audio for parking_meter: name 'tts' is not defined
# Generating for 'bench': bench yawonekera
# ❌ Error generating audio for bench: name 'tts' is not defined
# Generating for 'bird': bird yawonekera
# ❌ Error generating audio for bird: name 'tts' is not defined
# Generating for 'cat': cat yawonekera
# ❌ Error generating audio for cat: name 'tts' is not defined
# Generating for 'dog': dog yawonekera
# ❌ Error generating audio for dog: name 'tts' is not defined
# Generating for 'horse': horse yawonekera
# ❌ Error generating audio for horse: name 'tts' is not defined
# Generating for 'sheep': sheep yawonekera
# ❌ Error generating audio for sheep: name 'tts' is not defined
# Generating for 'cow': cow yawonekera
# ❌ Error generating audio for cow: name 'tts' is not defined
# Generating for 'elephant': elephant yawonekera
# ❌ Error generating audio for elephant: name 'tts' is not defined
# Generating for 'bear': bear yawonekera
# ❌ Error generating audio for bear: name 'tts' is not defined
# Generating for 'zebra': zebra yawonekera
# ❌ Error generating audio for zebra: name 'tts' is not defined
# Generating for 'giraffe': giraffe yawonekera
# ❌ Error generating audio for giraffe: name 'tts' is not defined
# Generating for 'hat': hat yawonekera
# ❌ Error generating audio for hat: name 'tts' is not defined
# Generating for 'backpack': backpack yawonekera
# ❌ Error generating audio for backpack: name 'tts' is not defined
# Generating for 'umbrella': umbrella yawonekera
# ❌ Error generating audio for umbrella: name 'tts' is not defined
# Generating for 'shoe': shoe yawonekera
# ❌ Error generating audio for shoe: name 'tts' is not defined
# Generating for 'eye_glasses': eye glasses yawonekera
# ❌ Error generating audio for eye_glasses: name 'tts' is not defined
# Generating for 'handbag': handbag yawonekera
# ❌ Error generating audio for handbag: name 'tts' is not defined
# Generating for 'tie': tie yawonekera
# ❌ Error generating audio for tie: name 'tts' is not defined
# Generating for 'suitcase': suitcase yawonekera
# ❌ Error generating audio for suitcase: name 'tts' is not defined
# Generating for 'frisbee': frisbee yawonekera
# ❌ Error generating audio for frisbee: name 'tts' is not defined
# Generating for 'skis': skis yawonekera
# ❌ Error generating audio for skis: name 'tts' is not defined
# Generating for 'snowboard': snowboard yawonekera
# ❌ Error generating audio for snowboard: name 'tts' is not defined
# Generating for 'sports_ball': sports ball yawonekera
# ❌ Error generating audio for sports_ball: name 'tts' is not defined
# Generating for 'kite': kite yawonekera
# ❌ Error generating audio for kite: name 'tts' is not defined
# Generating for 'baseball_bat': baseball bat yawonekera
# ❌ Error generating audio for baseball_bat: name 'tts' is not defined
# Generating for 'baseball_glove': baseball glove yawonekera
# ❌ Error generating audio for baseball_glove: name 'tts' is not defined
# Generating for 'skateboard': skateboard yawonekera
# ❌ Error generating audio for skateboard: name 'tts' is not defined
# Generating for 'surfboard': surfboard yawonekera
# ❌ Error generating audio for surfboard: name 'tts' is not defined
# Generating for 'tennis_racket': tennis racket yawonekera
# ❌ Error generating audio for tennis_racket: name 'tts' is not defined
# Generating for 'bottle': bottle yawonekera
# ❌ Error generating audio for bottle: name 'tts' is not defined
# Generating for 'plate': plate yawonekera
# ❌ Error generating audio for plate: name 'tts' is not defined
# Generating for 'wine_glass': wine glass yawonekera
# ❌ Error generating audio for wine_glass: name 'tts' is not defined
# Generating for 'cup': cup yawonekera
# ❌ Error generating audio for cup: name 'tts' is not defined
# Generating for 'fork': fork yawonekera
# ❌ Error generating audio for fork: name 'tts' is not defined
# Generating for 'knife': knife yawonekera
# ❌ Error generating audio for knife: name 'tts' is not defined
# Generating for 'spoon': spoon yawonekera
# ❌ Error generating audio for spoon: name 'tts' is not defined
# Generating for 'bowl': bowl yawonekera
# ❌ Error generating audio for bowl: name 'tts' is not defined
# Generating for 'banana': banana yawonekera
# ❌ Error generating audio for banana: name 'tts' is not defined
# Generating for 'apple': apple yawonekera
# ❌ Error generating audio for apple: name 'tts' is not defined
# Generating for 'sandwich': sandwich yawonekera
# ❌ Error generating audio for sandwich: name 'tts' is not defined
# Generating for 'orange': orange yawonekera
# ❌ Error generating audio for orange: name 'tts' is not defined
# Generating for 'broccoli': broccoli yawonekera
# ❌ Error generating audio for broccoli: name 'tts' is not defined
# Generating for 'carrot': carrot yawonekera
# ❌ Error generating audio for carrot: name 'tts' is not defined
# Generating for 'hot_dog': hot dog yawonekera
# ❌ Error generating audio for hot_dog: name 'tts' is not defined
# Generating for 'pizza': pizza yawonekera
# ❌ Error generating audio for pizza: name 'tts' is not defined
# Generating for 'donut': donut yawonekera
# ❌ Error generating audio for donut: name 'tts' is not defined
# Generating for 'cake': cake yawonekera
# ❌ Error generating audio for cake: name 'tts' is not defined
# Generating for 'chair': chair yawonekera
# ❌ Error generating audio for chair: name 'tts' is not defined
# Generating for 'couch': couch yawonekera
# ❌ Error generating audio for couch: name 'tts' is not defined
# Generating for 'potted_plant': potted plant yawonekera
# ❌ Error generating audio for potted_plant: name 'tts' is not defined
# Generating for 'bed': bed yawonekera
# ❌ Error generating audio for bed: name 'tts' is not defined
# Generating for 'mirror': mirror yawonekera
# ❌ Error generating audio for mirror: name 'tts' is not defined
# Generating for 'dining_table': dining table yawonekera
# ❌ Error generating audio for dining_table: name 'tts' is not defined
# Generating for 'window': window yawonekera
# ❌ Error generating audio for window: name 'tts' is not defined
# Generating for 'desk': desk yawonekera
# ❌ Error generating audio for desk: name 'tts' is not defined
# Generating for 'toilet': toilet yawonekera
# ❌ Error generating audio for toilet: name 'tts' is not defined
# Generating for 'door': door yawonekera
# ❌ Error generating audio for door: name 'tts' is not defined
# Generating for 'tv': tv yawonekera
# ❌ Error generating audio for tv: name 'tts' is not defined
# Generating for 'laptop': laptop yawonekera
# ❌ Error generating audio for laptop: name 'tts' is not defined
# Generating for 'mouse': mouse yawonekera
# ❌ Error generating audio for mouse: name 'tts' is not defined
# Generating for 'remote': remote yawonekera
# ❌ Error generating audio for remote: name 'tts' is not defined
# Generating for 'keyboard': keyboard yawonekera
# ❌ Error generating audio for keyboard: name 'tts' is not defined
# Generating for 'cell_phone': cell phone yawonekera
# ❌ Error generating audio for cell_phone: name 'tts' is not defined
# Generating for 'microwave': microwave yawonekera
# ❌ Error generating audio for microwave: name 'tts' is not defined
# Generating for 'oven': oven yawonekera
# ❌ Error generating audio for oven: name 'tts' is not defined
# Generating for 'toaster': toaster yawonekera
# ❌ Error generating audio for toaster: name 'tts' is not defined
# Generating for 'sink': sink yawonekera
# ❌ Error generating audio for sink: name 'tts' is not defined
# Generating for 'refrigerator': refrigerator yawonekera
# ❌ Error generating audio for refrigerator: name 'tts' is not defined
# Generating for 'blender': blender yawonekera
# ❌ Error generating audio for blender: name 'tts' is not defined
# Generating for 'book': book yawonekera
# ❌ Error generating audio for book: name 'tts' is not defined
# Generating for 'clock': clock yawonekera
# ❌ Error generating audio for clock: name 'tts' is not defined
# Generating for 'vase': vase yawonekera
# ❌ Error generating audio for vase: name 'tts' is not defined
# Generating for 'scissors': scissors yawonekera
# ❌ Error generating audio for scissors: name 'tts' is not defined
# Generating for 'teddy_bear': teddy bear yawonekera
# ❌ Error generating audio for teddy_bear: name 'tts' is not defined
# Generating for 'hair_drier': hair drier yawonekera
# ❌ Error generating audio for hair_drier: name 'tts' is not defined
# Generating for 'toothbrush': toothbrush yawonekera
# ❌ Error generating audio for toothbrush: name 'tts' is not defined
# Generating for 'hair_brush': hair brush yawonekera
# ❌ Error generating audio for hair_brush: name 'tts' is not defined
# Generating for 'banner': banner yawonekera
# ❌ Error generating audio for banner: name 'tts' is not defined
# Generating for 'blanket': blanket yawonekera
# ❌ Error generating audio for blanket: name 'tts' is not defined
# Generating for 'branch': branch yawonekera
# ❌ Error generating audio for branch: name 'tts' is not defined
# Generating for 'bridge': bridge yawonekera
# ❌ Error generating audio for bridge: name 'tts' is not defined
# Generating for 'buildingother': building-other yawonekera
# ❌ Error generating audio for buildingother: name 'tts' is not defined
# Generating for 'bush': bush yawonekera
# ❌ Error generating audio for bush: name 'tts' is not defined
# Generating for 'cabinet': cabinet yawonekera
# ❌ Error generating audio for cabinet: name 'tts' is not defined
# Generating for 'cage': cage yawonekera
# ❌ Error generating audio for cage: name 'tts' is not defined
# Generating for 'cardboard': cardboard yawonekera
# ❌ Error generating audio for cardboard: name 'tts' is not defined
# Generating for 'carpet': carpet yawonekera
# ❌ Error generating audio for carpet: name 'tts' is not defined
# Generating for 'ceilingother': ceiling-other yawonekera
# ❌ Error generating audio for ceilingother: name 'tts' is not defined
# Generating for 'ceilingtile': ceiling-tile yawonekera
# ❌ Error generating audio for ceilingtile: name 'tts' is not defined
# Generating for 'cloth': cloth yawonekera
# ❌ Error generating audio for cloth: name 'tts' is not defined
# Generating for 'clothes': clothes yawonekera
# ❌ Error generating audio for clothes: name 'tts' is not defined
# Generating for 'clouds': clouds yawonekera
# ❌ Error generating audio for clouds: name 'tts' is not defined
# Generating for 'counter': counter yawonekera
# ❌ Error generating audio for counter: name 'tts' is not defined
# Generating for 'cupboard': cupboard yawonekera
# ❌ Error generating audio for cupboard: name 'tts' is not defined
# Generating for 'curtain': curtain yawonekera
# ❌ Error generating audio for curtain: name 'tts' is not defined
# Generating for 'deskstuff': desk-stuff yawonekera
# ❌ Error generating audio for deskstuff: name 'tts' is not defined
# Generating for 'dirt': dirt yawonekera
# ❌ Error generating audio for dirt: name 'tts' is not defined
# Generating for 'doorstuff': door-stuff yawonekera
# ❌ Error generating audio for doorstuff: name 'tts' is not defined
# Generating for 'fence': fence yawonekera
# ❌ Error generating audio for fence: name 'tts' is not defined
# Generating for 'floormarble': floor-marble yawonekera
# ❌ Error generating audio for floormarble: name 'tts' is not defined
# Generating for 'floorother': floor-other yawonekera
# ❌ Error generating audio for floorother: name 'tts' is not defined
# Generating for 'floorstone': floor-stone yawonekera
# ❌ Error generating audio for floorstone: name 'tts' is not defined
# Generating for 'floortile': floor-tile yawonekera
# ❌ Error generating audio for floortile: name 'tts' is not defined
# Generating for 'floorwood': floor-wood yawonekera
# ❌ Error generating audio for floorwood: name 'tts' is not defined
# Generating for 'flower': flower yawonekera
# ❌ Error generating audio for flower: name 'tts' is not defined
# Generating for 'fog': fog yawonekera
# ❌ Error generating audio for fog: name 'tts' is not defined
# Generating for 'foodother': food-other yawonekera
# ❌ Error generating audio for foodother: name 'tts' is not defined
# Generating for 'fruit': fruit yawonekera
# ❌ Error generating audio for fruit: name 'tts' is not defined
# Generating for 'furnitureother': furniture-other yawonekera
# ❌ Error generating audio for furnitureother: name 'tts' is not defined
# Generating for 'grass': grass yawonekera
# ❌ Error generating audio for grass: name 'tts' is not defined
# Generating for 'gravel': gravel yawonekera
# ❌ Error generating audio for gravel: name 'tts' is not defined
# Generating for 'groundother': ground-other yawonekera
# ❌ Error generating audio for groundother: name 'tts' is not defined
# Generating for 'hill': hill yawonekera
# ❌ Error generating audio for hill: name 'tts' is not defined
# Generating for 'house': house yawonekera
# ❌ Error generating audio for house: name 'tts' is not defined
# Generating for 'leaves': leaves yawonekera
# ❌ Error generating audio for leaves: name 'tts' is not defined
# Generating for 'light': light yawonekera
# ❌ Error generating audio for light: name 'tts' is not defined
# Generating for 'mat': mat yawonekera
# ❌ Error generating audio for mat: name 'tts' is not defined
# Generating for 'metal': metal yawonekera
# ❌ Error generating audio for metal: name 'tts' is not defined
# Generating for 'mirrorstuff': mirror-stuff yawonekera
# ❌ Error generating audio for mirrorstuff: name 'tts' is not defined
# Generating for 'moss': moss yawonekera
# ❌ Error generating audio for moss: name 'tts' is not defined
# Generating for 'mountain': mountain yawonekera
# ❌ Error generating audio for mountain: name 'tts' is not defined
# Generating for 'mud': mud yawonekera
# ❌ Error generating audio for mud: name 'tts' is not defined
# Generating for 'napkin': napkin yawonekera
# ❌ Error generating audio for napkin: name 'tts' is not defined
# Generating for 'net': net yawonekera
# ❌ Error generating audio for net: name 'tts' is not defined
# Generating for 'paper': paper yawonekera
# ❌ Error generating audio for paper: name 'tts' is not defined
# Generating for 'pavement': pavement yawonekera
# ❌ Error generating audio for pavement: name 'tts' is not defined
# Generating for 'pillow': pillow yawonekera
# ❌ Error generating audio for pillow: name 'tts' is not defined
# Generating for 'plantother': plant-other yawonekera
# ❌ Error generating audio for plantother: name 'tts' is not defined
# Generating for 'plastic': plastic yawonekera
# ❌ Error generating audio for plastic: name 'tts' is not defined
# Generating for 'platform': platform yawonekera
# ❌ Error generating audio for platform: name 'tts' is not defined
# Generating for 'playingfield': playingfield yawonekera
# ❌ Error generating audio for playingfield: name 'tts' is not defined
# Generating for 'railing': railing yawonekera
# ❌ Error generating audio for railing: name 'tts' is not defined
# Generating for 'railroad': railroad yawonekera
# ❌ Error generating audio for railroad: name 'tts' is not defined
# Generating for 'river': river yawonekera
# ❌ Error generating audio for river: name 'tts' is not defined
# Generating for 'road': road yawonekera
# ❌ Error generating audio for road: name 'tts' is not defined
# Generating for 'rock': rock yawonekera
# ❌ Error generating audio for rock: name 'tts' is not defined
# Generating for 'roof': roof yawonekera
# ❌ Error generating audio for roof: name 'tts' is not defined
# Generating for 'rug': rug yawonekera
# ❌ Error generating audio for rug: name 'tts' is not defined
# Generating for 'salad': salad yawonekera
# ❌ Error generating audio for salad: name 'tts' is not defined
# Generating for 'sand': sand yawonekera
# ❌ Error generating audio for sand: name 'tts' is not defined
# Generating for 'sea': sea yawonekera
# ❌ Error generating audio for sea: name 'tts' is not defined
# Generating for 'shelf': shelf yawonekera
# ❌ Error generating audio for shelf: name 'tts' is not defined
# Generating for 'skyother': sky-other yawonekera
# ❌ Error generating audio for skyother: name 'tts' is not defined
# Generating for 'skyscraper': skyscraper yawonekera
# ❌ Error generating audio for skyscraper: name 'tts' is not defined
# Generating for 'snow': snow yawonekera
# ❌ Error generating audio for snow: name 'tts' is not defined
# Generating for 'solidother': solid-other yawonekera
# ❌ Error generating audio for solidother: name 'tts' is not defined
# Generating for 'stairway': stairway yawonekera
# ❌ Error generating audio for stairway: name 'tts' is not defined
# Generating for 'straw': straw yawonekera
# ❌ Error generating audio for straw: name 'tts' is not defined
# Generating for 'structuralother': structural-other yawonekera
# ❌ Error generating audio for structuralother: name 'tts' is not defined
# Generating for 'table': table yawonekera
# ❌ Error generating audio for table: name 'tts' is not defined
# Generating for 'tent': tent yawonekera
# ❌ Error generating audio for tent: name 'tts' is not defined
# Generating for 'textileother': textile-other yawonekera
# ❌ Error generating audio for textileother: name 'tts' is not defined
# Generating for 'towel': towel yawonekera
# ❌ Error generating audio for towel: name 'tts' is not defined
# Generating for 'tree': tree yawonekera
# ❌ Error generating audio for tree: name 'tts' is not defined
# Generating for 'vegetable': vegetable yawonekera
# ❌ Error generating audio for vegetable: name 'tts' is not defined
# Generating for 'wallbrick': wall-brick yawonekera
# ❌ Error generating audio for wallbrick: name 'tts' is not defined
# Generating for 'wallconcrete': wall-concrete yawonekera
# ❌ Error generating audio for wallconcrete: name 'tts' is not defined
# Generating for 'wallother': wall-other yawonekera
# ❌ Error generating audio for wallother: name 'tts' is not defined
# Generating for 'wallpanel': wall-panel yawonekera
# ❌ Error generating audio for wallpanel: name 'tts' is not defined
# Generating for 'wallstone': wall-stone yawonekera
# ❌ Error generating audio for wallstone: name 'tts' is not defined
# Generating for 'walltile': wall-tile yawonekera
# ❌ Error generating audio for walltile: name 'tts' is not defined
# Generating for 'wallwood': wall-wood yawonekera
# ❌ Error generating audio for wallwood: name 'tts' is not defined
# Generating for 'waterother': water-other yawonekera
# ❌ Error generating audio for waterother: name 'tts' is not defined
# Generating for 'waterdrops': water-drops yawonekera
# ❌ Error generating audio for waterdrops: name 'tts' is not defined
# Generating for 'windowblind': window-blind yawonekera
# ❌ Error generating audio for windowblind: name 'tts' is not defined
# Generating for 'windowother': window-other yawonekera
# ❌ Error generating audio for windowother: name 'tts' is not defined
# Generating for 'wood': wood yawonekera
# ❌ Error generating audio for wood: name 'tts' is not defined
#
# Audio files generated in 'bemba_audio_all/' directory
# Note: Replace with authentic Bemba recordings for production use.
